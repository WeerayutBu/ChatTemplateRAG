# %%
import pandas as pd
from pathlib import Path
from src.utils import FormatPrompt


system_prompt = Path(f"src/prompt/context_with_citations.md").read_text().strip()
FP = FormatPrompt("contextcitations")
# 1) INPUT:    user, meta_user = FP.format_input(q, facts=facts)
# 2) Extract:  FP.extract_output(out)
# 3) Format:   assistant, meta_assistant = FP.format_output(LLMs['answer'], LLMs['citations'])

# %% [markdown]
# ### Input format

# %%
q = "What is hiccup?"

facts = [
    {"id": 0, "title": "fact0"},
    {"id": 1, "title": "fact1"},
]

a, c = "answer", [0]
    
user, meta_user = FP.format_user(q, facts=facts)
assistant, meta_assistant = FP.format_assistant(a, c)

# a llm response: out = {'answer': 'string', 'citations': [0]}
out = assistant['content']  
out = FP.extract_response(out)
out['answer'], out['citations']
# Out:
# ('answer', [0])

# %%
pd.DataFrame([user])
# Out:
#    role                                            content
# 0  user  คำถาม:\nWhat is hiccup?\nFacts:\n[1] fact0\n[2...

# %%
pd.DataFrame([meta_user])
# Out:
#    role          content                                            context
# 0  user  What is hiccup?  [{"fid": 0, "text": "fact0"}, {"fid": 1, "text...

# %%
pd.DataFrame([assistant])
# Out:
#         role                                 content
# 0  assistant  {"answer": "answer", "citations": [0]}

# %%
pd.DataFrame([meta_assistant])
# Out:
#         role content llm_citations
# 0  assistant  answer           [0]
